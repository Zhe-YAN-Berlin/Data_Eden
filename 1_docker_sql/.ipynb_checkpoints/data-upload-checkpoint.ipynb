# %%
import pandas as pd
# Out:
# /tmp/ipykernel_5782/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
df = pd.read_csv('green_tripdata_2019-01.csv', nrows=100)

# %%
df
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0          2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1          2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2          2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3          2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4          2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
# ..       ...                  ...                   ...                ...
# 95         2  2019-01-01 00:15:42   2019-01-01 00:41:04                  N
# 96         2  2019-01-01 00:21:28   2019-01-01 00:48:15                  N
# 97         2  2019-01-01 00:17:10   2019-01-01 00:23:34                  N
# 98         2  2019-01-01 00:25:01   2019-01-01 00:43:55                  N
# 99         2  2019-01-01 00:36:56   2019-01-01 00:43:50                  N
#
#     RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0            1           264           264                5           0.00
# 1            1            97            49                2           0.86
# 2            1            49           189                2           0.66
# 3            1           189            17                2           2.68
# 4            1            82           258                1           4.53
# ..         ...           ...           ...              ...            ...
# 95           1            97           179                1           7.83
# 96           1             7           230                1           4.49
# 97           1            42            42                1           1.08
# 98           1            42           232                2           8.74
# 99           1           223             7                5           1.32
#
#     fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0           3.0    0.5      0.5        0.00           0.0        NaN
# 1           6.0    0.5      0.5        0.00           0.0        NaN
# 2           4.5    0.5      0.5        0.00           0.0        NaN
# 3          13.5    0.5      0.5        2.96           0.0        NaN
# 4          18.0    0.5      0.5        0.00           0.0        NaN
# ..          ...    ...      ...         ...           ...        ...
# 95         26.0    0.5      0.5        5.46           0.0        NaN
# 96         20.0    0.5      0.5        4.00           0.0        NaN
# 97          6.5    0.5      0.5        0.00           0.0        NaN
# 98         25.0    0.5      0.5        0.00           0.0        NaN
# 99          7.0    0.5      0.5        2.00           0.0        NaN
#
#     improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                     0.3          4.30             2          1
# 1                     0.3          7.30             2          1
# 2                     0.3          5.80             1          1
# 3                     0.3         19.71             1          1
# 4                     0.3         19.30             2          1
# ..                    ...           ...           ...        ...
# 95                    0.3         32.76             1          1
# 96                    0.3         25.30             1          1
# 97                    0.3          7.80             2          1
# 98                    0.3         26.30             2          1
# 99                    0.3         10.30             1          1
#
#     congestion_surcharge
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 95                   NaN
# 96                   NaN
# 97                   NaN
# 98                   NaN
# 99                   NaN
#
# [100 rows x 20 columns]

# %%
print(pd.io.sql.get_schema(df, name = 'green_texi_data'))
# Out:
# CREATE TABLE "green_texi_data" (
# "VendorID" INTEGER,
#   "lpep_pickup_datetime" TEXT,
#   "lpep_dropoff_datetime" TEXT,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" INTEGER,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" INTEGER,
#   "trip_type" INTEGER,
#   "congestion_surcharge" REAL
# )

# %%
pd.to_datetime(df.lpep_pickup_datetime)
# Out:
# 0    2018-12-21 15:17:29
# 1    2019-01-01 00:10:16
# 2    2019-01-01 00:27:11
# 3    2019-01-01 00:46:20
# 4    2019-01-01 00:19:06
#              ...
# 95   2019-01-01 00:15:42
# 96   2019-01-01 00:21:28
# 97   2019-01-01 00:17:10
# 98   2019-01-01 00:25:01
# 99   2019-01-01 00:36:56
# Name: lpep_pickup_datetime, Length: 100, dtype: datetime64[ns]

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
from sqlalchemy import create_engine

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3282, in Engine.raw_connection(self)
#    3261 """Return a "raw" DBAPI connection from the connection pool.
#    3262
#    3263 The returned object is a proxied version of the DBAPI
#    (...)
#    3280
#    3281 """
# -> 3282 return self.pool.connect()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:168, in QueuePool._do_get(self)
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:166, in QueuePool._do_get(self)
#     165 try:
# --> 166     return self._create_connection()
#     167 except:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[14], line 3
#       1 from sqlalchemy import create_engine
#       2 engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
# ----> 3 engine.connect()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3258, in Engine.connect(self)
#    3235 def connect(self) -> Connection:
#    3236     """Return a new :class:`_engine.Connection` object.
#    3237
#    3238     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3255
#    3256     """
# -> 3258     return self._connection_cls(self)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2422, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2420 elif should_wrap:
#    2421     assert sqlalchemy_exception is not None
# -> 2422     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2423 else:
#    2424     assert exc_info[1] is not None
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3282, in Engine.raw_connection(self)
#    3260 def raw_connection(self) -> PoolProxiedConnection:
#    3261     """Return a "raw" DBAPI connection from the connection pool.
#    3262
#    3263     The returned object is a proxied version of the DBAPI
#    (...)
#    3280
#    3281     """
# -> 3282     return self.pool.connect()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:168, in QueuePool._do_get(self)
#     166     return self._create_connection()
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#     170     raise
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:166, in QueuePool._do_get(self)
#     164 if self._inc_overflow():
#     165     try:
# --> 166         return self._create_connection()
#     167     except:
#     168         with util.safe_reraise():
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
print(pd.io.sql.get_schema(df, name = 'green_texi_data', con=engine))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3282, in Engine.raw_connection(self)
#    3261 """Return a "raw" DBAPI connection from the connection pool.
#    3262
#    3263 The returned object is a proxied version of the DBAPI
#    (...)
#    3280
#    3281 """
# -> 3282 return self.pool.connect()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:168, in QueuePool._do_get(self)
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:166, in QueuePool._do_get(self)
#     165 try:
# --> 166     return self._create_connection()
#     167 except:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(pd.io.sql.get_schema(df, name = 'green_texi_data', con=engine))
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:2924, in get_schema(frame, name, keys, con, dtype, schema)
#    2895 def get_schema(
#    2896     frame,
#    2897     name: str,
#    (...)
#    2901     schema: str | None = None,
#    2902 ) -> str:
#    2903     """
#    2904     Get the SQL db table schema for the given frame.
#    2905
#    (...)
#    2922         Optional specifying the schema to be used in creating the table.
#    2923     """
# -> 2924     with pandasSQL_builder(con=con) as pandas_sql:
#    2925         return pandas_sql._create_sql_schema(
#    2926             frame, name, keys=keys, dtype=dtype, schema=schema
#    2927         )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:1639, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1637     self.exit_stack.callback(con.dispose)
#    1638 if isinstance(con, Engine):
# -> 1639     con = self.exit_stack.enter_context(con.connect())
#    1640 if need_transaction and not con.in_transaction():
#    1641     self.exit_stack.enter_context(con.begin())
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3258, in Engine.connect(self)
#    3235 def connect(self) -> Connection:
#    3236     """Return a new :class:`_engine.Connection` object.
#    3237
#    3238     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3255
#    3256     """
# -> 3258     return self._connection_cls(self)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2422, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2420 elif should_wrap:
#    2421     assert sqlalchemy_exception is not None
# -> 2422     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2423 else:
#    2424     assert exc_info[1] is not None
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3282, in Engine.raw_connection(self)
#    3260 def raw_connection(self) -> PoolProxiedConnection:
#    3261     """Return a "raw" DBAPI connection from the connection pool.
#    3262
#    3263     The returned object is a proxied version of the DBAPI
#    (...)
#    3280
#    3281     """
# -> 3282     return self.pool.connect()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:168, in QueuePool._do_get(self)
#     166     return self._create_connection()
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#     170     raise
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:166, in QueuePool._do_get(self)
#     164 if self._inc_overflow():
#     165     try:
# --> 166         return self._create_connection()
#     167     except:
#     168         with util.safe_reraise():
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
df_iter = pd.read_csv('green_tripdata_2019-01.csv', iterator=True, chunksize=100000)

# %%
df_iter = pd.read_csv('green_tripdata_2019-01.csv', iterator=True, chunksize=100000)
df=next(df_iter)
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1             2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2             2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3             2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4             2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-01-06 09:56:09   2019-01-06 10:01:30                  N
# 99996         2  2019-01-06 09:12:49   2019-01-06 09:52:38                  N
# 99997         2  2019-01-06 09:02:06   2019-01-06 09:37:42                  N
# 99998         2  2019-01-06 09:55:01   2019-01-06 10:04:34                  N
# 99999         2  2019-01-06 09:59:04   2019-01-06 10:24:33                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0               1           264           264                5           0.00
# 1               1            97            49                2           0.86
# 2               1            49           189                2           0.66
# 3               1           189            17                2           2.68
# 4               1            82           258                1           4.53
# ...           ...           ...           ...              ...            ...
# 99995           1           130           216                1           1.23
# 99996           5           218            16                1          21.44
# 99997           5           139           188                1          14.77
# 99998           1            72           188                1           1.80
# 99999           5            89           225                1           7.03
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             3.00    0.5      0.5        0.00          0.00        NaN
# 1             6.00    0.5      0.5        0.00          0.00        NaN
# 2             4.50    0.5      0.5        0.00          0.00        NaN
# 3            13.50    0.5      0.5        2.96          0.00        NaN
# 4            18.00    0.5      0.5        0.00          0.00        NaN
# ...            ...    ...      ...         ...           ...        ...
# 99995         6.00    0.0      0.5        0.00          0.00        NaN
# 99996        47.65    0.0      0.5        0.00          5.76        NaN
# 99997        37.84    0.0      0.5        0.00          0.00        NaN
# 99998         8.50    0.0      0.5        0.00          0.00        NaN
# 99999        23.14    0.0      0.5        0.00          0.00        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          4.30             2          1
# 1                        0.3          7.30             2          1
# 2                        0.3          5.80             1          1
# 3                        0.3         19.71             1          1
# 4                        0.3         19.30             2          1
# ...                      ...           ...           ...        ...
# 99995                    0.3          6.80             2          1
# 99996                    0.0         53.91             1          2
# 99997                    0.0         38.34             1          2
# 99998                    0.3          9.30             1          1
# 99999                    0.0         23.64             1          2
#
#        congestion_surcharge
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 99995                   NaN
# 99996                   NaN
# 99997                   NaN
# 99998                   NaN
# 99999                   NaN
#
# [100000 rows x 20 columns]

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime) #text转timestamp
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1         2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2         2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3         2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4         2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           264           264                5           0.00
# 1           1            97            49                2           0.86
# 2           1            49           189                2           0.66
# 3           1           189            17                2           2.68
# 4           1            82           258                1           4.53
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          3.0    0.5      0.5        0.00           0.0        NaN
# 1          6.0    0.5      0.5        0.00           0.0        NaN
# 2          4.5    0.5      0.5        0.00           0.0        NaN
# 3         13.5    0.5      0.5        2.96           0.0        NaN
# 4         18.0    0.5      0.5        0.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3          4.30             2          1
# 1                    0.3          7.30             2          1
# 2                    0.3          5.80             1          1
# 3                    0.3         19.71             1          1
# 4                    0.3         19.30             2          1
#
#    congestion_surcharge
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
df.head(n=0)
# Out:
# Empty DataFrame
# Columns: [VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge]
# Index: []

# %%
df.to_sql(name = 'green_texi_data', con=engine,if_exists='replace')
# Out:
# 1000

# %%
df.head(n=0).to_sql(name = 'green_texi_data',con=engine,if_exists='replace')
# Out:
# 0

# %%
df.head(n=0).to_sql(name = 'green_texi_data',con=engine,if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='green_texi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 6.12 s, sys: 35.7 ms, total: 6.15 s
# Wall time: 8.49 s
# 1000

# %%
while Ture:
	df = next(df_iter)
	df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime) #text转timestamp
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.to_sql(name='green_texi_data', con=engine, if_exists='append')
    print('insert another chunk'')
# Out:
#   File <tokenize>:4
#     df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
from time import time
while True:
    t_start=time()
    df = next(df_iter)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime) #text转timestamp
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.to_sql(name='green_texi_data', con=engine, if_exists='append')
    t_end = time()
    print('insert another chunk... took %.3f sec' % (t_end - t_start))
# Out:
# insert another chunk... took %.3f sec%(t_end-t_start)
# insert another chunk... took %.3f sec%(t_end-t_start)
# insert another chunk... took %.3f sec%(t_end-t_start)
# insert another chunk... took %.3f sec%(t_end-t_start)
# insert another chunk... took %.3f sec%(t_end-t_start)
# insert another chunk... took %.3f sec%(t_end-t_start)
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[37], line 4
#       2 while True:
#       3     t_start=time()
# ----> 4     df = next(df_iter)
#       5     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime) #text转timestamp
#       6     df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1841, in TextFileReader.__next__(self)
#    1839 def __next__(self) -> DataFrame:
#    1840     try:
# -> 1841         return self.get_chunk()
#    1842     except StopIteration:
#    1843         self.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1983, in TextFileReader.get_chunk(self, size)
#    1981         raise StopIteration
#    1982     size = min(size, self.nrows - self._currow)
# -> 1983 return self.read(nrows=size)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1921, in TextFileReader.read(self, nrows)
#    1914 nrows = validate_integer("nrows", nrows)
#    1915 try:
#    1916     # error: "ParserBase" has no attribute "read"
#    1917     (
#    1918         index,
#    1919         columns,
#    1920         col_dict,
# -> 1921     ) = self._engine.read(  # type: ignore[attr-defined]
#    1922         nrows
#    1923     )
#    1924 except Exception:
#    1925     self.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:863, in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:

# %%
print('insert another chunk... took %.3f sec' % (t_end - t_start))
# Out:
# insert another chunk... took -0.000 sec

# %%
df = pd.read_csv('green_tripdata_2019-01.csv')

# %%
len(df)
# Out:
# 630918
